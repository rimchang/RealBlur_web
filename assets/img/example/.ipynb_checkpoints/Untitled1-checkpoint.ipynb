# %%
import scipy
import matplotlib.pyplot as plt

# %%
import imageio

# %%
img=imageio.imread('example4.png')

# %%
width = 600
height = 250

s_w = 0
s_h = 300
plt.imshow(img[s_h:s_h+height, s_w:s_w+width, :])

# %%
imageio.imsave('crop_example5.png', img[s_h:s_h+height, s_w:s_w+width, :])
